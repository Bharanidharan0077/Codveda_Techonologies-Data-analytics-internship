# %% [markdown]
# # Level 3 Task 2: Building Dashboard with Power BI

# %% [markdown]
# # 1.Import Libraries

# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/dhine/Downloads/2) Stock Prices Data Set (1).csv")

# %%
df.shape
# Out:
# (497472, 7)

# %%
df.head(10)
# Out:
#   symbol        date      open      high       low     close    volume
# 0    AAL  2014-01-02   25.0700   25.8200   25.0600   25.3600   8998943
# 1   AAPL  2014-01-02   79.3828   79.5756   78.8601   79.0185  58791957
# 2    AAP  2014-01-02  110.3600  111.8800  109.2900  109.7400    542711
# 3   ABBV  2014-01-02   52.1200   52.3300   51.5200   51.9800   4569061
# 4    ABC  2014-01-02   70.1100   70.2300   69.4800   69.8900   1148391
# 5    ABT  2014-01-02   38.0900   38.4000   38.0000   38.2300   4967472
# 6    ACN  2014-01-02   81.5000   81.9200   81.0900   81.1300   2405384
# 7   ADBE  2014-01-02   59.0600   59.5300   58.9400   59.2900   2746370
# 8    ADI  2014-01-02   49.5200   49.7500   49.0400   49.2800   2799092
# 9    ADM  2014-01-02   43.2200   43.2900   42.7900   42.9900   2753765

# %%
df.isnull().sum()
# Out:
# symbol     0
# date       0
# open      11
# high       8
# low        8
# close      0
# volume     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497472 entries, 0 to 497471
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   symbol  497472 non-null  object
#  1   date    497472 non-null  object
#  2   open    497461 non-null  float64
#  3   high    497464 non-null  float64
#  4   low     497464 non-null  float64
#  5   close   497472 non-null  float64
#  6   volume  497472 non-null  int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 26.6+ MB

# %%
df = df.dropna()
df = df.drop_duplicates()

# %%
df['symbol'].nunique()
# Out:
# 505

# %%
df['symbol'].value_counts()
# Out:
# symbol
# ZTS     1007
# AAL     1007
# AAPL    1007
# URI     1007
# USB     1007
#         ...
# DXC      189
# BHGE     126
# BHF      116
# DWDP      83
# APTV      18
# Name: count, Length: 505, dtype: int64

# %% [markdown]
# ### Feature engineering

# %%
df['date'].min(), df['date'].max()
# Out:
# (Timestamp('2014-01-02 00:00:00'), Timestamp('2017-12-29 00:00:00'))

# %%
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['month_name'] = df['date'].dt.month_name()
df['quarter'] = df['date'].dt.quarter
df['day'] = df['date'].dt.day

# %%
df.head()
# Out:
#   symbol       date      open      high       low     close    volume  year  \
# 0    AAL 2014-01-02   25.0700   25.8200   25.0600   25.3600   8998943  2014
# 1   AAPL 2014-01-02   79.3828   79.5756   78.8601   79.0185  58791957  2014
# 2    AAP 2014-01-02  110.3600  111.8800  109.2900  109.7400    542711  2014
# 3   ABBV 2014-01-02   52.1200   52.3300   51.5200   51.9800   4569061  2014
# 4    ABC 2014-01-02   70.1100   70.2300   69.4800   69.8900   1148391  2014
#
#    month month_name  quarter  day
# 0      1    January        1    2
# 1      1    January        1    2
# 2      1    January        1    2
# 3      1    January        1    2
# 4      1    January        1    2

# %%
df['daily_change'] = df['close'] - df['open']

# %%
df['price_range'] = df['high'] - df['low']

# %%
df['return_pct'] = ((df['close'] - df['open']) / df['open']) * 100

# %%
df.head()
# Out:
#   symbol       date      open      high       low     close    volume  year  \
# 0    AAL 2014-01-02   25.0700   25.8200   25.0600   25.3600   8998943  2014
# 1   AAPL 2014-01-02   79.3828   79.5756   78.8601   79.0185  58791957  2014
# 2    AAP 2014-01-02  110.3600  111.8800  109.2900  109.7400    542711  2014
# 3   ABBV 2014-01-02   52.1200   52.3300   51.5200   51.9800   4569061  2014
# 4    ABC 2014-01-02   70.1100   70.2300   69.4800   69.8900   1148391  2014
#
#    month month_name  quarter  day  daily_change  price_range  return_pct
# 0      1    January        1    2        0.2900       0.7600    1.156761
# 1      1    January        1    2       -0.3643       0.7155   -0.458916
# 2      1    January        1    2       -0.6200       2.5900   -0.561798
# 3      1    January        1    2       -0.1400       0.8100   -0.268611
# 4      1    January        1    2       -0.2200       0.7500   -0.313793

# %% [markdown]
# ### Save the file

# %%
df.to_csv("C:/Users/dhine/Downloads/2) Stock Prices Data Set (1).csv",index = False)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Read the image
img = mpimg.imread("C:/Users/dhine/Pictures/Screenshots/Screenshot 2026-04-02 142435.png")

# Plot the image
plt.imshow(img)
plt.axis('off') # Hide axes
plt.show()
